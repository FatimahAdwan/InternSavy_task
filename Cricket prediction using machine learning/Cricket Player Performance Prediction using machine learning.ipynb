# %% [markdown]
# # Import Libraries

# %%
# Disable all warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error as mae, mean_squared_error as mse

# %% [markdown]
# * #### Load the Data
#
# the data came in different sheet which we have to load and look at one after the other

# %%
bats_df = pd.read_csv("Batsman_Data.csv")
bats_df.head(3)
# Out:
#    Unnamed: 0 Bat1 Runs BF SR 4s 6s Opposition   Ground Start Date  \
# 0           1  DNB    -  -  -  -  -    v India   Nagpur  18-Dec-09
# 1           2  DNB    -  -  -  -  -    v India  Kolkata  24-Dec-09
# 2           3  DNB    -  -  -  -  -    v India    Delhi  27-Dec-09
#
#      Match_ID        Batsman  Player_ID
# 0  ODI # 2933  Oshane Thomas      49619
# 1  ODI # 2935  Oshane Thomas      49619
# 2  ODI # 2936  Oshane Thomas      49619

# %%
bats_df.shape
# Out:
# (11149, 13)

# %%
bowl_df = pd.read_csv("Bowler_data.csv")
bowl_df.head(3)
# Out:
#    Unnamed: 0 Overs Mdns Runs Wkts  Econ    Ave    SR Opposition   Ground  \
# 0           1   8.0    0   57    0  7.12      -     -    v India   Nagpur
# 1           2  10.0    0   55    2  5.50  27.50  30.0    v India  Kolkata
# 2           3     -    -    -    -     -      -     -    v India    Delhi
#
#     Start Date    Match_ID          Bowler  Player_ID
# 0  18 Dec 2009  ODI # 2933  Suranga Lakmal      49619
# 1  24 Dec 2009  ODI # 2935  Suranga Lakmal      49619
# 2  27 Dec 2009  ODI # 2936  Suranga Lakmal      49619

# %%
bowl_df.shape
# Out:
# (11118, 14)

# %%
ground_df = pd.read_csv("Ground_Averages.csv")
ground_df.head(3)
# Out:
#                                  Ground       Span  Mat  Won  Tied  NR  Runs  \
# 0         Eden Gardens, Kolkata - India  2013-2017    4    4     0   0  2161
# 1       Feroz Shah Kotla, Delhi - India  2013-2019    4    4     0   0  1789
# 2  Melbourne Cricket Ground - Australia  2013-2019   15   15     0   0  7656
#
#    Wkts  Balls    Ave   RPO
# 0    72   2297  30.01  5.64
# 1    75   2331  23.85  4.60
# 2   217   8482  35.28  5.41

# %%
ground_df.shape
# Out:
# (106, 11)

# %%
match_results = pd.read_csv("ODI_Match_Results.csv")
match_results.head(3)
# Out:
#    Unnamed: 0 Result   Margin  BR  Toss  Bat  Opposition   Ground  Start Date  \
# 0         418    won  85 runs NaN  lost  1st     v India  Kolkata  3 Jan 2013
# 1         692   lost  85 runs NaN   won  2nd  v Pakistan  Kolkata  3 Jan 2013
# 2         419   lost  10 runs NaN  lost  2nd     v India    Delhi  6 Jan 2013
#
#      Match_ID   Country  Country_ID
# 0  ODI # 3315  Pakistan           7
# 1  ODI # 3315     India           6
# 2  ODI # 3316  Pakistan           7

# %%
match_results.shape
# Out:
# (1322, 12)

# %%
match_totals = pd.read_csv("ODI_Match_Totals.csv")
match_totals.head(3)
# Out:
#    Unnamed: 0 Score  Overs   RPO  Target  Inns Result  Opposition   Ground  \
# 0         412   250   48.3  5.15     NaN     1    won     v India  Kolkata
# 1         680   165   48.0  3.43   251.0     2   lost  v Pakistan  Kolkata
# 2         413   157   48.5  3.21   168.0     2   lost     v India    Delhi
#
#    Start Date    Match_ID   Country  Country_ID
# 0  3 Jan 2013  ODI # 3315  Pakistan           7
# 1  3 Jan 2013  ODI # 3315     India           6
# 2  6 Jan 2013  ODI # 3316  Pakistan           7

# %%
match_totals.shape
# Out:
# (1296, 13)

# %%
wc_player = pd.read_csv("WC_players.csv")
wc_player.head(3)
# Out:
#               Player      ID      Country
# 0  Gulbadin Naib (c)  352048  Afghanistan
# 1   Rashid Khan (vc)  793463  Afghanistan
# 2         Aftab Alam  440963  Afghanistan

# %%
wc_player.shape
# Out:
# (152, 3)

# %% [markdown]
# * #### Look at the Data

# %%
bats_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Bat1          0
# Runs          0
# BF            0
# SR            0
# 4s            0
# 6s            0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Batsman       0
# Player_ID     0
# dtype: int64

# %%
bowl_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Overs         0
# Mdns          0
# Runs          0
# Wkts          0
# Econ          0
# Ave           0
# SR            0
# Opposition    0
# Ground        0
# Start Date    0
# Match_ID      0
# Bowler        0
# Player_ID     0
# dtype: int64

# %%
ground_df.isnull().sum()
# Out:
# Ground    0
# Span      0
# Mat       0
# Won       0
# Tied      0
# NR        0
# Runs      0
# Wkts      0
# Balls     0
# Ave       0
# RPO       0
# dtype: int64

# %%
match_results.isnull().sum()
# Out:
# Unnamed: 0      0
# Result          0
# Margin          0
# BR            716
# Toss            0
# Bat             0
# Opposition      0
# Ground          0
# Start Date      0
# Match_ID        0
# Country         0
# Country_ID      0
# dtype: int64

# %%
match_totals.isnull().sum()
# Out:
# Unnamed: 0      0
# Score           0
# Overs           0
# RPO             0
# Target        676
# Inns            0
# Result          0
# Opposition      0
# Ground          0
# Start Date      0
# Match_ID        0
# Country         0
# Country_ID      0
# dtype: int64

# %%
wc_player.isnull().sum()
# Out:
# Player     0
# ID         0
# Country    0
# dtype: int64

# %%
bats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11149 entries, 0 to 11148
# Data columns (total 13 columns):
# Unnamed: 0    11149 non-null int64
# Bat1          11149 non-null object
# Runs          11149 non-null object
# BF            11149 non-null object
# SR            11149 non-null object
# 4s            11149 non-null object
# 6s            11149 non-null object
# Opposition    11149 non-null object
# Ground        11149 non-null object
# Start Date    11149 non-null object
# Match_ID      11149 non-null object
# Batsman       11149 non-null object
# Player_ID     11149 non-null int64
# dtypes: int64(2), object(11)
# memory usage: 1.1+ MB

# %%
bowl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11118 entries, 0 to 11117
# Data columns (total 14 columns):
# Unnamed: 0    11118 non-null int64
# Overs         11118 non-null object
# Mdns          11118 non-null object
# Runs          11118 non-null object
# Wkts          11118 non-null object
# Econ          11118 non-null object
# Ave           11118 non-null object
# SR            11118 non-null object
# Opposition    11118 non-null object
# Ground        11118 non-null object
# Start Date    11118 non-null object
# Match_ID      11118 non-null object
# Bowler        11118 non-null object
# Player_ID     11118 non-null int64
# dtypes: int64(2), object(12)
# memory usage: 1.2+ MB

# %%
ground_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 11 columns):
# Ground    106 non-null object
# Span      106 non-null object
# Mat       106 non-null int64
# Won       106 non-null int64
# Tied      106 non-null int64
# NR        106 non-null int64
# Runs      106 non-null int64
# Wkts      106 non-null int64
# Balls     106 non-null int64
# Ave       106 non-null float64
# RPO       106 non-null float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 9.2+ KB

# %%
match_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1322 entries, 0 to 1321
# Data columns (total 12 columns):
# Unnamed: 0    1322 non-null int64
# Result        1322 non-null object
# Margin        1322 non-null object
# BR            606 non-null float64
# Toss          1322 non-null object
# Bat           1322 non-null object
# Opposition    1322 non-null object
# Ground        1322 non-null object
# Start Date    1322 non-null object
# Match_ID      1322 non-null object
# Country       1322 non-null object
# Country_ID    1322 non-null int64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 124.1+ KB

# %%
match_totals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 13 columns):
# Unnamed: 0    1296 non-null int64
# Score         1296 non-null object
# Overs         1296 non-null float64
# RPO           1296 non-null object
# Target        620 non-null float64
# Inns          1296 non-null int64
# Result        1296 non-null object
# Opposition    1296 non-null object
# Ground        1296 non-null object
# Start Date    1296 non-null object
# Match_ID      1296 non-null object
# Country       1296 non-null object
# Country_ID    1296 non-null int64
# dtypes: float64(2), int64(3), object(8)
# memory usage: 131.8+ KB

# %%
wc_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 3 columns):
# Player     152 non-null object
# ID         152 non-null int64
# Country    152 non-null object
# dtypes: int64(1), object(2)
# memory usage: 3.7+ KB

# %%
df=[bats_df,bowl_df,ground_df,match_results,match_totals,wc_player]

# %%
# lets check statistics summary
def stat_summary(df):
    for i in df:
        print(i.describe(include='all'))
        print('_'*100)

# %%
stat_summary(df)
# Out:
#          Unnamed: 0   Bat1   Runs     BF     SR     4s     6s   Opposition  \
# count   11149.00000  11149  11149  11149  11149  11149  11149        11149
# unique          NaN    323    180    163   2032     26     17           22
# top             NaN    DNB      -      -      -      0      0  v Sri Lanka
# freq            NaN   2043   2231   2231   2331   2901   6368         1283
# mean     5575.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# std      3218.58341    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# min         1.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# 25%      2788.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# 50%      5575.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# 75%      8362.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
# max     11149.00000    NaN    NaN    NaN    NaN    NaN    NaN          NaN
#
#        Ground Start Date    Match_ID    Batsman     Player_ID
# count   11149      11149       11149      11149  1.114900e+04
# unique    134       1625        1844        149           NaN
# top     Dhaka  19-Jan-18  ODI # 3980  MS Dhoni            NaN
# freq      839         50          22        341           NaN
# mean      NaN        NaN         NaN        NaN  2.259088e+05
# std       NaN        NaN         NaN        NaN  1.942613e+05
# min       NaN        NaN         NaN        NaN  5.334000e+03
# 25%       NaN        NaN         NaN        NaN  4.749200e+04
# 50%       NaN        NaN         NaN        NaN  2.335140e+05
# 75%       NaN        NaN         NaN        NaN  3.217770e+05
# max       NaN        NaN         NaN        NaN  1.158100e+06
# ____________________________________________________________________________________________________
#           Unnamed: 0  Overs   Mdns   Runs   Wkts   Econ    Ave     SR  \
# count   11118.000000  11118  11118  11118  11118  11118  11118  11118
# unique           NaN     61      6    100      9    517    250    135
# top              NaN      -      -      -      -      -      -      -
# freq             NaN   5270   5270   5270   5270   5270   7498   7498
# mean     5559.500000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# std      3209.634481    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# min         1.000000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 25%      2780.250000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 50%      5559.500000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 75%      8338.750000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# max     11118.000000    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#          Opposition Ground   Start Date    Match_ID     Bowler     Player_ID
# count         11118  11118        11118       11118      11118  1.111800e+04
# unique           22    134         1624        1842        150           NaN
# top     v Sri Lanka  Dhaka  19 Jan 2018  ODI # 3989  MS Dhoni            NaN
# freq           1283    839           50          22        341           NaN
# mean            NaN    NaN          NaN         NaN        NaN  2.254082e+05
# std             NaN    NaN          NaN         NaN        NaN  1.936517e+05
# min             NaN    NaN          NaN         NaN        NaN  5.334000e+03
# 25%             NaN    NaN          NaN         NaN        NaN  4.557200e+04
# 50%             NaN    NaN          NaN         NaN        NaN  2.335140e+05
# 75%             NaN    NaN          NaN         NaN        NaN  3.217770e+05
# max             NaN    NaN          NaN         NaN        NaN  1.158100e+06
# ____________________________________________________________________________________________________
#                                               Ground       Span         Mat  \
# count                                            106        106  106.000000
# unique                                           106         20         NaN
# top     Sabina Park, Kingston, Jamaica - West Indies  2013-2019         NaN
# freq                                               1         28         NaN
# mean                                             NaN        NaN    7.792453
# std                                              NaN        NaN    8.285061
# min                                              NaN        NaN    1.000000
# 25%                                              NaN        NaN    2.250000
# 50%                                              NaN        NaN    5.000000
# 75%                                              NaN        NaN   10.000000
# max                                              NaN        NaN   50.000000
#
#                Won        Tied          NR          Runs        Wkts  \
# count   106.000000  106.000000  106.000000    106.000000  106.000000
# unique         NaN         NaN         NaN           NaN         NaN
# top            NaN         NaN         NaN           NaN         NaN
# freq           NaN         NaN         NaN           NaN         NaN
# mean      7.367925    0.094340    0.311321   3582.500000  112.103774
# std       8.022974    0.324501    0.622793   3575.148949  122.883602
# min       1.000000    0.000000    0.000000    209.000000    6.000000
# 25%       2.000000    0.000000    0.000000   1239.250000   34.000000
# 50%       5.000000    0.000000    0.000000   2283.500000   75.000000
# 75%      10.000000    0.000000    0.000000   4759.500000  137.250000
# max      50.000000    2.000000    3.000000  20917.000000  739.000000
#
#                Balls         Ave         RPO
# count     106.000000  106.000000  106.000000
# unique           NaN         NaN         NaN
# top              NaN         NaN         NaN
# freq             NaN         NaN         NaN
# mean     4031.896226   34.216604    5.458113
# std      4296.526140   11.367913    0.756841
# min       252.000000   15.540000    3.880000
# 25%      1229.000000   28.800000    4.990000
# 50%      2777.500000   32.775000    5.440000
# 75%      5279.500000   36.282500    5.757500
# max     26328.000000  120.160000    9.690000
# ____________________________________________________________________________________________________
#          Unnamed: 0 Result     Margin          BR  Toss   Bat   Opposition  \
# count   1322.000000   1322       1322  606.000000  1322  1322         1322
# unique          NaN      7        173         NaN     3     3           18
# top             NaN    won  6 wickets         NaN  lost   1st  v Sri Lanka
# freq            NaN    663        114         NaN   657   656          146
# mean     661.500000    NaN        NaN   51.409241   NaN   NaN          NaN
# std      381.772838    NaN        NaN   55.924337   NaN   NaN          NaN
# min        1.000000    NaN        NaN    0.000000   NaN   NaN          NaN
# 25%      331.250000    NaN        NaN   10.000000   NaN   NaN          NaN
# 50%      661.500000    NaN        NaN   30.500000   NaN   NaN          NaN
# 75%      991.750000    NaN        NaN   75.000000   NaN   NaN          NaN
# max     1322.000000    NaN        NaN  250.000000   NaN   NaN          NaN
#
#        Ground   Start Date    Match_ID   Country   Country_ID
# count    1322         1322        1322      1322  1322.000000
# unique     94          649         759        10          NaN
# top     Dhaka  19 Jan 2018  ODI # 4067  SriLanka          NaN
# freq       75            6           2       162          NaN
# mean      NaN          NaN         NaN       NaN     8.560514
# std       NaN          NaN         NaN       NaN    10.337003
# min       NaN          NaN         NaN       NaN     1.000000
# 25%       NaN          NaN         NaN       NaN     3.000000
# 50%       NaN          NaN         NaN       NaN     5.000000
# 75%       NaN          NaN         NaN       NaN     8.000000
# max       NaN          NaN         NaN       NaN    40.000000
# ____________________________________________________________________________________________________
#          Unnamed: 0 Score        Overs   RPO      Target         Inns Result  \
# count   1296.000000  1296  1296.000000  1296  620.000000  1296.000000   1296
# unique          NaN   864          NaN   395         NaN          NaN      5
# top             NaN   DNB          NaN     -         NaN          NaN    won
# freq            NaN    20          NaN    20         NaN          NaN    663
# mean     648.500000   NaN    43.087423   NaN  253.440323     1.462963    NaN
# std      374.267284   NaN    10.632343   NaN   70.004394     0.528875    NaN
# min        1.000000   NaN     0.000000   NaN   68.000000     0.000000    NaN
# 25%      324.750000   NaN    40.200000   NaN  208.750000     1.000000    NaN
# 50%      648.500000   NaN    48.200000   NaN  258.000000     1.000000    NaN
# 75%      972.250000   NaN    50.000000   NaN  301.000000     2.000000    NaN
# max     1296.000000   NaN    50.000000   NaN  482.000000     2.000000    NaN
#
#          Opposition Ground   Start Date    Match_ID   Country   Country_ID
# count          1296   1296         1296        1296      1296  1296.000000
# unique           18     94          635         742        10          NaN
# top     v Sri Lanka  Dhaka  19 Jan 2018  ODI # 3681  SriLanka          NaN
# freq            146     75            6           2       160          NaN
# mean            NaN    NaN          NaN         NaN       NaN     8.553241
# std             NaN    NaN          NaN         NaN       NaN    10.330236
# min             NaN    NaN          NaN         NaN       NaN     1.000000
# 25%             NaN    NaN          NaN         NaN       NaN     3.000000
# 50%             NaN    NaN          NaN         NaN       NaN     5.000000
# 75%             NaN    NaN          NaN         NaN       NaN     8.000000
# max             NaN    NaN          NaN         NaN       NaN    40.000000
# ____________________________________________________________________________________________________
#                      Player            ID    Country
# count                   152  1.520000e+02        152
# unique                  152           NaN         10
# top     Milinda Siriwardana           NaN  Australia
# freq                      1           NaN         16
# mean                    NaN  3.542758e+05        NaN
# std                     NaN  2.361571e+05        NaN
# min                     NaN  5.334000e+03        NaN
# 25%                     NaN  2.298578e+05        NaN
# 50%                     NaN  3.230675e+05        NaN
# 75%                     NaN  4.942175e+05        NaN
# max                     NaN  1.158100e+06        NaN
# ____________________________________________________________________________________________________

# %%
# As our data set has start date or date column so lets first seaprate them into day, month and year wise and drop the orignal one
def seperate_date(df):
    for i in range(len(df)):
        if 'Start Date' in df[i].columns:
            df[i]['Year']=pd.to_datetime(df[i]['Start Date'])
            df[i]['Month']=df[i]['Year'].apply(lambda x:x.month) # Extracting Month
            df[i]['Day']=df[i]['Year'].apply(lambda x:x.day)  # Extracting day
            df[i]['year']=df[i]['Year'].apply(lambda x:x.year)  # Extracting year
            print(df[i].head())
            print("-------------------------")
        else:
            print("DataFrame", i, "does not have 'Start Date' column")
            print("-------------------------")

# %%
seperate_date(df)
# Out:
#    Unnamed: 0 Bat1 Runs BF SR 4s 6s    Opposition   Ground Start Date  \
# 0           1  DNB    -  -  -  -  -       v India   Nagpur  18-Dec-09
# 1           2  DNB    -  -  -  -  -       v India  Kolkata  24-Dec-09
# 2           3  DNB    -  -  -  -  -       v India    Delhi  27-Dec-09
# 3           4  DNB    -  -  -  -  -  v Bangladesh    Dhaka   4-Jan-10
# 4           5  DNB    -  -  -  -  -       v India    Dhaka   5-Jan-10
#
#      Match_ID        Batsman  Player_ID       Year  Month  Day  year
# 0  ODI # 2933  Oshane Thomas      49619 2009-12-18     12   18  2009
# 1  ODI # 2935  Oshane Thomas      49619 2009-12-24     12   24  2009
# 2  ODI # 2936  Oshane Thomas      49619 2009-12-27     12   27  2009
# 3  ODI # 2937  Oshane Thomas      49619 2010-01-04      1    4  2010
# 4  ODI # 2938  Oshane Thomas      49619 2010-01-05      1    5  2010
# -------------------------
#    Unnamed: 0 Overs Mdns Runs Wkts  Econ    Ave    SR    Opposition   Ground  \
# 0           1   8.0    0   57    0  7.12      -     -       v India   Nagpur
# 1           2  10.0    0   55    2  5.50  27.50  30.0       v India  Kolkata
# 2           3     -    -    -    -     -      -     -       v India    Delhi
# 3           4   9.0    1   63    2  7.00  31.50  27.0  v Bangladesh    Dhaka
# 4           5   8.0    1   48    0  6.00      -     -       v India    Dhaka
#
#     Start Date    Match_ID          Bowler  Player_ID       Year  Month  Day  \
# 0  18 Dec 2009  ODI # 2933  Suranga Lakmal      49619 2009-12-18     12   18
# 1  24 Dec 2009  ODI # 2935  Suranga Lakmal      49619 2009-12-24     12   24
# 2  27 Dec 2009  ODI # 2936  Suranga Lakmal      49619 2009-12-27     12   27
# 3   4 Jan 2010  ODI # 2937  Suranga Lakmal      49619 2010-01-04      1    4
# 4   5 Jan 2010  ODI # 2938  Suranga Lakmal      49619 2010-01-05      1    5
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2010
# 4  2010
# -------------------------
# DataFrame 2 does not have 'Start Date' column
# -------------------------
#    Unnamed: 0 Result    Margin  BR  Toss  Bat   Opposition     Ground  \
# 0         418    won   85 runs NaN  lost  1st      v India    Kolkata
# 1         692   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata
# 2         419   lost   10 runs NaN  lost  2nd      v India      Delhi
# 3         693    won   10 runs NaN   won  1st   v Pakistan      Delhi
# 4         121   lost  107 runs NaN  lost  2nd  v Australia  Melbourne
#
#     Start Date    Match_ID   Country  Country_ID       Year  Month  Day  year
# 0   3 Jan 2013  ODI # 3315  Pakistan           7 2013-01-03      1    3  2013
# 1   3 Jan 2013  ODI # 3315     India           6 2013-01-03      1    3  2013
# 2   6 Jan 2013  ODI # 3316  Pakistan           7 2013-01-06      1    6  2013
# 3   6 Jan 2013  ODI # 3316     India           6 2013-01-06      1    6  2013
# 4  11 Jan 2013  ODI # 3317  SriLanka           8 2013-01-11      1   11  2013
# -------------------------
#    Unnamed: 0 Score  Overs   RPO  Target  Inns Result   Opposition     Ground  \
# 0         412   250   48.3  5.15     NaN     1    won      v India    Kolkata
# 1         680   165   48.0  3.43   251.0     2   lost   v Pakistan    Kolkata
# 2         413   157   48.5  3.21   168.0     2   lost      v India      Delhi
# 3         681   167   43.4  3.82     NaN     1    won   v Pakistan      Delhi
# 4         117   198   40.0  4.95   306.0     2   lost  v Australia  Melbourne
#
#     Start Date    Match_ID   Country  Country_ID       Year  Month  Day  year
# 0   3 Jan 2013  ODI # 3315  Pakistan           7 2013-01-03      1    3  2013
# 1   3 Jan 2013  ODI # 3315     India           6 2013-01-03      1    3  2013
# 2   6 Jan 2013  ODI # 3316  Pakistan           7 2013-01-06      1    6  2013
# 3   6 Jan 2013  ODI # 3316     India           6 2013-01-06      1    6  2013
# 4  11 Jan 2013  ODI # 3317  SriLanka           8 2013-01-11      1   11  2013
# -------------------------
# DataFrame 5 does not have 'Start Date' column
# -------------------------

# %%
# Drop irrelavent columns from the datasets
def drop_irrelevant(df):
    for i in range(len(df)):
        columns_to_drop = ['Unnamed: 0', 'Start Date', 'Year']
        irrelevant_columns = [col for col in columns_to_drop if col in df[i].columns]
        
        if irrelevant_columns:
            df[i].drop(columns=irrelevant_columns, axis=1, inplace=True)
            print("DataFrame", i, "after dropping irrelevant columns:")
            print(df[i].head())  # Printing the DataFrame after dropping columns
            print("-------------------------")
        else:
            print("DataFrame", i, "does not have any irrelevant columns")
            print("-------------------------")

# %%
drop_irrelevant(df)
# Out:
# DataFrame 0 after dropping irrelevant columns:
#   Bat1 Runs BF SR 4s 6s    Opposition   Ground    Match_ID        Batsman  \
# 0  DNB    -  -  -  -  -       v India   Nagpur  ODI # 2933  Oshane Thomas
# 1  DNB    -  -  -  -  -       v India  Kolkata  ODI # 2935  Oshane Thomas
# 2  DNB    -  -  -  -  -       v India    Delhi  ODI # 2936  Oshane Thomas
# 3  DNB    -  -  -  -  -  v Bangladesh    Dhaka  ODI # 2937  Oshane Thomas
# 4  DNB    -  -  -  -  -       v India    Dhaka  ODI # 2938  Oshane Thomas
#
#    Player_ID  Month  Day  year
# 0      49619     12   18  2009
# 1      49619     12   24  2009
# 2      49619     12   27  2009
# 3      49619      1    4  2010
# 4      49619      1    5  2010
# -------------------------
# DataFrame 1 after dropping irrelevant columns:
#   Overs Mdns Runs Wkts  Econ    Ave    SR    Opposition   Ground    Match_ID  \
# 0   8.0    0   57    0  7.12      -     -       v India   Nagpur  ODI # 2933
# 1  10.0    0   55    2  5.50  27.50  30.0       v India  Kolkata  ODI # 2935
# 2     -    -    -    -     -      -     -       v India    Delhi  ODI # 2936
# 3   9.0    1   63    2  7.00  31.50  27.0  v Bangladesh    Dhaka  ODI # 2937
# 4   8.0    1   48    0  6.00      -     -       v India    Dhaka  ODI # 2938
#
#            Bowler  Player_ID  Month  Day  year
# 0  Suranga Lakmal      49619     12   18  2009
# 1  Suranga Lakmal      49619     12   24  2009
# 2  Suranga Lakmal      49619     12   27  2009
# 3  Suranga Lakmal      49619      1    4  2010
# 4  Suranga Lakmal      49619      1    5  2010
# -------------------------
# DataFrame 2 does not have any irrelevant columns
# -------------------------
# DataFrame 3 after dropping irrelevant columns:
#   Result    Margin  BR  Toss  Bat   Opposition     Ground    Match_ID  \
# 0    won   85 runs NaN  lost  1st      v India    Kolkata  ODI # 3315
# 1   lost   85 runs NaN   won  2nd   v Pakistan    Kolkata  ODI # 3315
# 2   lost   10 runs NaN  lost  2nd      v India      Delhi  ODI # 3316
# 3    won   10 runs NaN   won  1st   v Pakistan      Delhi  ODI # 3316
# 4   lost  107 runs NaN  lost  2nd  v Australia  Melbourne  ODI # 3317
#
#     Country  Country_ID  Month  Day  year
# 0  Pakistan           7      1    3  2013
# 1     India           6      1    3  2013
# 2  Pakistan           7      1    6  2013
# 3     India           6      1    6  2013
# 4  SriLanka           8      1   11  2013
# -------------------------
# DataFrame 4 after dropping irrelevant columns:
#   Score  Overs   RPO  Target  Inns Result   Opposition     Ground    Match_ID  \
# 0   250   48.3  5.15     NaN     1    won      v India    Kolkata  ODI # 3315
# 1   165   48.0  3.43   251.0     2   lost   v Pakistan    Kolkata  ODI # 3315
# 2   157   48.5  3.21   168.0     2   lost      v India      Delhi  ODI # 3316
# 3   167   43.4  3.82     NaN     1    won   v Pakistan      Delhi  ODI # 3316
# 4   198   40.0  4.95   306.0     2   lost  v Australia  Melbourne  ODI # 3317
#
#     Country  Country_ID  Month  Day  year
# 0  Pakistan           7      1    3  2013
# 1     India           6      1    3  2013
# 2  Pakistan           7      1    6  2013
# 3     India           6      1    6  2013
# 4  SriLanka           8      1   11  2013
# -------------------------
# DataFrame 5 does not have any irrelevant columns
# -------------------------

# %%
df_list=[bats_df,bowl_df,ground_df,match_results,match_totals,wc_player]

# %%
# As we seen there are object type of data availabe in the all the dataset so lets separate them and encode them into numeric form .
# lets seaprate the catogorical data & numirical data

numerics = ['int8', 'int16', 'int32', 'int64', 'float16', 'float32', 'float64']

def get_categorical_columns(df_list):
    cat_col_list = []  # List to store categorical column names for each DataFrame

    for df in df_list:
        cat_col = []  # List to store categorical column names for the current DataFrame
        features = df.columns.values.tolist()

        for col in features:
            if df[col].dtype not in numerics:  # Check if the column's data type is non-numeric
                cat_col.append(col)

        cat_col_list.append(cat_col)

    return cat_col_list

def label_encode_categorical_columns(df_list):
    label = LabelEncoder()

    categorical_columns_list = get_categorical_columns(df_list)

    for i, cat_col in enumerate(categorical_columns_list):
        for col in cat_col:
            encoded_values = label.fit_transform(df_list[i][col])
            df_list[i][col] = encoded_values

# %%
label_encode_categorical_columns(df_list)

# %%
bats_df.head(3)
# Out:
#    Bat1  Runs  BF  SR  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0   319     0   0   0   0   0           9      92       759      113
# 1   319     0   0   0   0   0           9      78       761      113
# 2   319     0   0   0   0   0           9      37       762      113
#
#    Player_ID  Month  Day  year
# 0      49619     12   18  2009
# 1      49619     12   24  2009
# 2      49619     12   27  2009

# %%
bowl_df.head(3)
# Out:
#    Overs  Mdns  Runs  Wkts  Econ  Ave  SR  Opposition  Ground  Match_ID  \
# 0     49     1    59     1   412    0   0           9      92       759
# 1     12     1    57     3   316  103  77           9      78       761
# 2      0     0     0     0     0    0   0           9      37       762
#
#    Bowler  Player_ID  Month  Day  year
# 0     138      49619     12   18  2009
# 1     138      49619     12   24  2009
# 2     138      49619     12   27  2009

# %%
ground_df.head(3)
# Out:
#    Ground  Span  Mat  Won  Tied  NR  Runs  Wkts  Balls    Ave   RPO
# 0      23     4    4    4     0   0  2161    72   2297  30.01  5.64
# 1      26     6    4    4     0   0  1789    75   2331  23.85  4.60
# 2      55     6   15   15     0   0  7656   217   8482  35.28  5.41

# %%
match_results.head(3)
# Out:
#    Result  Margin  BR  Toss  Bat  Opposition  Ground  Match_ID  Country  \
# 0       6     160 NaN     1    1           5      57         0        6
# 1       3     160 NaN     2    2          11      57         0        4
# 2       3       3 NaN     1    2           5      29         1        6
#
#    Country_ID  Month  Day  year
# 0           7      1    3  2013
# 1           6      1    3  2013
# 2           7      1    6  2013

# %%
match_totals.head(3)
# Out:
#    Score  Overs  RPO  Target  Inns  Result  Opposition  Ground  Match_ID  \
# 0    404   48.3  165     NaN     1       4           5      57         0
# 1    115   48.0   25   251.0     2       1          11      57         0
# 2     93   48.5   18   168.0     2       1           5      29         1
#
#    Country  Country_ID  Month  Day  year
# 0        6           7      1    3  2013
# 1        4           6      1    3  2013
# 2        6           7      1    6  2013

# %%
wc_player.head(3)
# Out:
#    Player      ID  Country
# 0      42  352048        0
# 1     118  793463        0
# 2       5  440963        0

# %%
match_results.isnull().sum()
# Out:
# Result          0
# Margin          0
# BR            716
# Toss            0
# Bat             0
# Opposition      0
# Ground          0
# Match_ID        0
# Country         0
# Country_ID      0
# Month           0
# Day             0
# year            0
# dtype: int64

# %%
match_totals.isnull().sum()
# Out:
# Score           0
# Overs           0
# RPO             0
# Target        676
# Inns            0
# Result          0
# Opposition      0
# Ground          0
# Match_ID        0
# Country         0
# Country_ID      0
# Month           0
# Day             0
# year            0
# dtype: int64

# %%
# lets treat missing values
imputer = IterativeImputer()
df_list2 = [match_results,match_totals]

def treat_missing_value(df_list2):
    for i in range(len(df_list2)):
        df_imputed = imputer.fit_transform(df_list2[i])
        df_list2[i] = pd.DataFrame(df_imputed, columns=df_list2[i].columns)
        print("DataFrame", i, "after imputation:")
        print(df_list2[i].isnull().sum()) #Lets Check the Values treated well or not
        print("-------------------------")

# %%
treat_missing_value(df_list2)
# Out:
# DataFrame 0 after imputation:
# Result        0
# Margin        0
# BR            0
# Toss          0
# Bat           0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# -------------------------
# DataFrame 1 after imputation:
# Score         0
# Overs         0
# RPO           0
# Target        0
# Inns          0
# Result        0
# Opposition    0
# Ground        0
# Match_ID      0
# Country       0
# Country_ID    0
# Month         0
# Day           0
# year          0
# dtype: int64
# -------------------------

# %%
match_totals=df_list2[0]
match_results=df_list2[1]

# %%
bats_df
# Out:
#        Bat1  Runs   BF    SR  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0       319     0    0     0   0   0           9      92       759      113
# 1       319     0    0     0   0   0           9      78       761      113
# 2       319     0    0     0   0   0           9      37       762      113
# 3       319     0    0     0   0   0           4      38       763      113
# 4       319     0    0     0   0   0           9      38       764      113
# ...     ...   ...  ...   ...  ..  ..         ...     ...       ...      ...
# 11144   203   121  121  1409  22   2          10      36      1809       42
# 11145   167   103  119   969   1   1          10      36      1810       42
# 11146     2     2  141   330   1   1          10      36      1817       42
# 11147   319     0    0     0   0   0          16      46      1834       42
# 11148   320     0    0     0   0   0          10       8      1842       42
#
#        Player_ID  Month  Day  year
# 0          49619     12   18  2009
# 1          49619     12   24  2009
# 2          49619     12   27  2009
# 3          49619      1    4  2010
# 4          49619      1    5  2010
# ...          ...    ...  ...   ...
# 11144     352048      2   28  2019
# 11145     352048      3    2  2019
# 11146     352048      3    8  2019
# 11147     352048      5   10  2019
# 11148     352048      5   19  2019
#
# [11149 rows x 14 columns]

# %%
bowl_df
# Out:
#        Overs  Mdns  Runs  Wkts  Econ  Ave  SR  Opposition  Ground  Match_ID  \
# 0         49     1    59     1   412    0   0           9      92       759
# 1         12     1    57     3   316  103  77           9      78       761
# 2          0     0     0     0     0    0   0           9      37       762
# 3         55     2    66     3   406  120  70           4      38       763
# 4         49     2    49     1   349    0   0           9      38       764
# ...      ...   ...   ...   ...   ...  ...  ..         ...     ...       ...
# 11113     25     1    42     1    35    0   0           9      40      1758
# 11114     45     1    19     3   112    5  60          10      36      1809
# 11115      0     0     0     0     0    0   0          10      36      1810
# 11116     37     1    20     2   171   80  83          10      36      1817
# 11117     12     1    76     4   417   92  56          16      46      1834
#
#        Bowler  Player_ID  Month  Day  year
# 0         138      49619     12   18  2009
# 1         138      49619     12   24  2009
# 2         138      49619     12   27  2009
# 3         138      49619      1    4  2010
# 4         138      49619      1    5  2010
# ...       ...        ...    ...  ...   ...
# 11113      42     352048      9   25  2018
# 11114      42     352048      2   28  2019
# 11115      42     352048      3    2  2019
# 11116      42     352048      3    8  2019
# 11117      42     352048      5   10  2019
#
# [11118 rows x 15 columns]

# %%
ground_df
# Out:
#      Ground  Span  Mat  Won  Tied  NR  Runs  Wkts  Balls    Ave   RPO
# 0        23     4    4    4     0   0  2161    72   2297  30.01  5.64
# 1        26     6    4    4     0   0  1789    75   2331  23.85  4.60
# 2        55     6   15   15     0   0  7656   217   8482  35.28  5.41
# 3        76     2    2    2     0   0  1163    26   1200  44.73  5.81
# 4         0     6   10   10     0   0  4863   157   5645  30.97  5.16
# ..      ...   ...  ...  ...   ...  ..   ...   ...    ...    ...   ...
# 101      32    18    1    1     0   0   209    11    280  19.00  4.47
# 102      90    18    1    1     0   0   400    11    531  36.36  4.51
# 103      70    19    5    4     0   1  1864    67   2524  27.82  4.43
# 104     100    19    1    1     0   0   307    17    474  18.05  3.88
# 105       1    19    1    1     0   0   329    15    460  21.93  4.29
#
# [106 rows x 11 columns]

# %%
#Lets Create a master dataset and then build the model 
# so first we are going to merge 2 dataset and then further  
batsman_join_bowler=pd.merge(bats_df,bowl_df,on=['Match_ID','Player_ID','Opposition','Ground','Month','Day','year'], how='inner')
batsman_join_bowler
# Out:
#        Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0       319       0    0     0   0   0           9      92       759      113
# 1       319       0    0     0   0   0           9      78       761      113
# 2       319       0    0     0   0   0           9      37       762      113
# 3       319       0    0     0   0   0           4      38       763      113
# 4       319       0    0     0   0   0           9      38       764      113
# ...     ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 11113    99      57  104   826   2   1           9      40      1758       42
# 11114   203     121  121  1409  22   2          10      36      1809       42
# 11115   167     103  119   969   1   1          10      36      1810       42
# 11116     2       2  141   330   1   1          10      36      1817       42
# 11117   319       0    0     0   0   0          16      46      1834       42
#
#        ...  Day  year  Overs  Mdns  Runs_y  Wkts  Econ  Ave  SR_y  Bowler
# 0      ...   18  2009     49     1      59     1   412    0     0     138
# 1      ...   24  2009     12     1      57     3   316  103    77     138
# 2      ...   27  2009      0     0       0     0     0    0     0     138
# 3      ...    4  2010     55     2      66     3   406  120    70     138
# 4      ...    5  2010     49     2      49     1   349    0     0     138
# ...    ...  ...   ...    ...   ...     ...   ...   ...  ...   ...     ...
# 11113  ...   25  2018     25     1      42     1    35    0     0      42
# 11114  ...   28  2019     45     1      19     3   112    5    60      42
# 11115  ...    2  2019      0     0       0     0     0    0     0      42
# 11116  ...    8  2019     37     1      20     2   171   80    83      42
# 11117  ...   10  2019     12     1      76     4   417   92    56      42
#
# [11118 rows x 22 columns]

# %%
batsman_join_bowler.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts', 'Econ', 'Ave', 'SR_y', 'Bowler'],
#       dtype='object')

# %%
bowl_df.columns
# Out:
# Index(['Overs', 'Mdns', 'Runs', 'Wkts', 'Econ', 'Ave', 'SR', 'Opposition',
#        'Ground', 'Match_ID', 'Bowler', 'Player_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join ground_df
batsman_join_bowler_GrondAvg=pd.merge(batsman_join_bowler,ground_df,on=['Ground'], how='inner')
batsman_join_bowler_GrondAvg
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition  Ground  Match_ID  Batsman  \
# 0      319       0    0     0   0   0           9      92       759      113
# 1       12       7   21  1757  24  10           9      92        84       20
# 2      217     128  104   240   3   1           9      92       391       20
# 3      184     111   81   572  20   1           9      92       759       11
# 4      319       0    0     0   0   0           9      92       927       25
# ...    ...     ...  ...   ...  ..  ..         ...     ...       ...      ...
# 9074   217     128  117  1780  22   2          10      36      1817      117
# 9075   180     109   84   389  13   9          10      36      1819      117
# 9076   203     121  121  1409  22   2          10      36      1809       42
# 9077   167     103  119   969   1   1          10      36      1810       42
# 9078     2       2  141   330   1   1          10      36      1817       42
#
#       ...  Span  Mat  Won  Tied  NR  Runs  Wkts_y  Balls  Ave_y   RPO
# 0     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 1     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 2     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 3     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# 4     ...     6   16   14     0   2  6890     202   7508  34.10  5.50
# ...   ...   ...  ...  ...   ...  ..   ...     ...    ...    ...   ...
# 9074  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9075  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9076  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9077  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
# 9078  ...     4    4    4     0   0  1664      56   1987  29.71  5.02
#
# [9079 rows x 32 columns]

# %%
batsman_join_bowler_GrondAvg.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO'],
#       dtype='object')

# %%
match_results.columns
# Out:
# Index(['Score', 'Overs', 'RPO', 'Target', 'Inns', 'Result', 'Opposition',
#        'Ground', 'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
match_totals.columns
# Out:
# Index(['Result', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition', 'Ground',
#        'Match_ID', 'Country', 'Country_ID', 'Month', 'Day', 'year'],
#       dtype='object')

# %%
#Lets Join match_results & match_totals
OD_Total_result=pd.merge(match_results,match_totals,on=['Ground','Country','Country_ID','Month','Day','year','Opposition'], how='inner')
OD_Total_result
# Out:
#       Score  Overs    RPO      Target  Inns  Result_x  Opposition  Ground  \
# 0     404.0   48.3  165.0  241.723435   1.0       4.0         5.0    57.0
# 1     115.0   48.0   25.0  251.000000   2.0       1.0        11.0    57.0
# 2      93.0   48.5   18.0  168.000000   2.0       1.0         5.0    29.0
# 3     120.0   43.4   48.0  176.027214   1.0       4.0        11.0    29.0
# 4     199.0   40.0  146.0  306.000000   2.0       1.0         1.0    63.0
# ...     ...    ...    ...         ...   ...       ...         ...     ...
# 1291  750.0   50.0  309.0  382.947700   1.0       1.0         3.0    72.0
# 1292  753.0   49.3  315.0  341.000000   2.0       4.0        11.0    72.0
# 1293   27.0   33.0   38.0  211.000000   2.0       0.0         6.0     7.0
# 1294  187.0   31.5  249.0  352.000000   2.0       0.0         3.0    60.0
# 1295  767.0   50.0  322.0  406.462269   1.0       0.0        11.0    60.0
#
#       Match_ID_x  Country  Country_ID  Month   Day    year  Result_y  Margin  \
# 0            0.0      6.0         7.0    1.0   3.0  2013.0       6.0   160.0
# 1            0.0      4.0         6.0    1.0   3.0  2013.0       3.0   160.0
# 2            1.0      6.0         7.0    1.0   6.0  2013.0       3.0     3.0
# 3            1.0      4.0         6.0    1.0   6.0  2013.0       6.0     3.0
# 4            2.0      8.0         8.0    1.0  11.0  2013.0       3.0    10.0
# ...          ...      ...         ...    ...   ...     ...       ...     ...
# 1291       739.0      6.0         7.0    5.0  17.0  2019.0       3.0    99.0
# 1292       739.0      3.0         1.0    5.0  17.0  2019.0       6.0    99.0
# 1293       740.0      0.0        40.0    5.0  19.0  2019.0       0.0     0.0
# 1294       741.0      6.0         7.0    5.0  19.0  2019.0       0.0     0.0
# 1295       741.0      3.0         1.0    5.0  19.0  2019.0       0.0     0.0
#
#              BR  Toss  Bat  Match_ID_y
# 0     52.000182   1.0  1.0         0.0
# 1     52.728414   2.0  2.0         0.0
# 2     20.689046   1.0  2.0         1.0
# 3     21.548194   2.0  1.0         1.0
# 4     19.527705   1.0  2.0         2.0
# ...         ...   ...  ...         ...
# 1291   3.000000   1.0  1.0       755.0
# 1292   3.000000   2.0  2.0       755.0
# 1293  32.327406   2.0  2.0       757.0
# 1294  29.815762   1.0  2.0       758.0
# 1295  31.063998   2.0  1.0       758.0
#
# [1296 rows x 20 columns]

# %%
#Lets Join batsman_join_bowler_GrondAvg & OD_Total_result
batsman_join_bowler_GrondAvg_OD=pd.merge(batsman_join_bowler_GrondAvg,OD_Total_result,on=['Ground','Month','Day','year'], how='inner')
batsman_join_bowler_GrondAvg_OD
# Out:
#       Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  \
# 0      140      86   14   677   1   1            15       1      1225
# 1      140      86   14   677   1   1            15       1      1225
# 2        0       1  108     1   1   1            15       1      1225
# 3        0       1  108     1   1   1            15       1      1225
# 4      277     158  141     4   2   1            15       1      1225
# ...    ...     ...  ...   ...  ..  ..           ...     ...       ...
# 1039   191     115  131  1056   2   2            10      36      1819
# 1040   284     161   16  1375  22   9            10      36      1819
# 1041   284     161   16  1375  22   9            10      36      1819
# 1042   180     109   84   389  13   9            10      36      1819
# 1043   180     109   84   389  13   9            10      36      1819
#
#       Batsman  ...  Opposition_y  Match_ID_x  Country  Country_ID  Result_y  \
# 0         113  ...          11.0       123.0      8.0         8.0       3.0
# 1         113  ...          14.0       123.0      6.0         7.0       6.0
# 2          80  ...          11.0       123.0      8.0         8.0       3.0
# 3          80  ...          14.0       123.0      6.0         7.0       6.0
# 4          78  ...          11.0       123.0      8.0         8.0       3.0
# ...       ...  ...           ...         ...      ...         ...       ...
# 1039       99  ...          14.0       719.0      7.0         3.0       6.0
# 1040       13  ...          13.0       719.0      8.0         8.0       3.0
# 1041       13  ...          14.0       719.0      7.0         3.0       6.0
# 1042      117  ...          13.0       719.0      8.0         8.0       3.0
# 1043      117  ...          14.0       719.0      7.0         3.0       6.0
#
#       Margin         BR  Toss  Bat  Match_ID_y
# 0      154.0  53.000000   2.0  1.0       126.0
# 1      154.0  53.000000   1.0  2.0       126.0
# 2      154.0  53.000000   2.0  1.0       126.0
# 3      154.0  53.000000   1.0  2.0       126.0
# 4      154.0  53.000000   2.0  1.0       126.0
# ...      ...        ...   ...  ...         ...
# 1039   144.0  63.153507   1.0  1.0       733.0
# 1040   144.0  62.762323   2.0  2.0       733.0
# 1041   144.0  63.153507   1.0  1.0       733.0
# 1042   144.0  62.762323   2.0  2.0       733.0
# 1043   144.0  63.153507   1.0  1.0       733.0
#
# [1044 rows x 48 columns]

# %%
batsman_join_bowler_GrondAvg_OD.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns', 'Result_x',
#        'Opposition_y', 'Match_ID_x', 'Country', 'Country_ID', 'Result_y',
#        'Margin', 'BR', 'Toss', 'Bat', 'Match_ID_y'],
#       dtype='object')

# %%
wc_player=wc_player.rename(columns={'ID':'Player_ID'})

# %%
#Lets Join batsman_join_bowler_GrondAvg_OD & wc_player
master_after_join=pd.merge(batsman_join_bowler_GrondAvg_OD,wc_player,on=['Player_ID','Country'], how='inner')
master_after_join
# Out:
#      Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0       0       1  108     1   1   1            15       1      1225       80
# 1       0       1    2     1   1   1            15       1      1227       80
# 2       2       2  130   518   1   1             0       1      1750       80
# 3     319       0    0     0   0   0             3       2      1106       80
# 4     277     158  141     4   2   1            15       1      1225       78
# ..    ...     ...  ...   ...  ..  ..           ...     ...       ...      ...
# 505   319       0    0     0   0   0            13       5      1590        9
# 506   154      96  109   946  18   1            17       5      1590       93
# 507     5       3  130   535  13   1            15       5      1485       93
# 508   255     147   74   849   1   1             3       5      1574       93
# 509   180     109   96  1782   2   9             3       5      1486       93
#
#      ...  Match_ID_x  Country  Country_ID  Result_y  Margin          BR  Toss  \
# 0    ...       123.0      8.0         8.0       3.0   154.0   53.000000   2.0
# 1    ...       125.0      8.0         8.0       6.0    73.0    2.000000   1.0
# 2    ...       648.0      8.0         8.0       3.0   167.0   67.891460   1.0
# 3    ...         4.0      8.0         8.0       6.0   154.0   59.000000   2.0
# 4    ...       123.0      8.0         8.0       3.0   154.0   53.000000   2.0
# ..   ...         ...      ...         ...       ...     ...         ...   ...
# 505  ...       488.0      7.0         3.0       6.0   131.0  106.000000   2.0
# 506  ...       488.0      5.0         5.0       3.0   131.0  106.000000   1.0
# 507  ...       383.0      5.0         5.0       6.0    99.0    2.000000   1.0
# 508  ...       472.0      5.0         5.0       6.0   130.0   57.891035   1.0
# 509  ...       384.0      5.0         5.0       6.0    54.0   38.654344   1.0
#
#      Bat  Match_ID_y  Player
# 0    1.0       126.0      80
# 1    2.0       128.0      80
# 2    2.0       662.0      80
# 3    2.0         4.0      80
# 4    1.0       126.0      78
# ..   ...         ...     ...
# 505  2.0       501.0       9
# 506  1.0       501.0      94
# 507  2.0       393.0      94
# 508  1.0       484.0      94
# 509  1.0       394.0      94
#
# [510 rows x 49 columns]

# %%
# Calculate Batting Average for each player
master_after_join['Batting Average'] = master_after_join['Bat1'] / master_after_join['Inns']

# %%
# Display the Batting Average for each player
print(master_after_join[['Player', 'Batting Average']])
# Out:
#      Player  Batting Average
# 0        80              0.0
# 1        80              0.0
# 2        80              1.0
# 3        80            159.5
# 4        78            277.0
# ..      ...              ...
# 505       9            159.5
# 506      94            154.0
# 507      94              2.5
# 508      94            255.0
# 509      94            180.0
#
# [510 rows x 2 columns]

# %%
# Calculate Bowling Average for each player
master_after_join['Bowling Average'] = master_after_join['Runs_y'] / master_after_join['Wkts_y']

# Display the Bowling Average for each player
print(master_after_join[['Player', 'Bowling Average']])
# Out:
#      Player  Bowling Average
# 0        80         2.733333
# 1        80         3.933333
# 2        80         4.600000
# 3        80         0.941176
# 4        78         0.000000
# ..      ...              ...
# 505       9         0.729167
# 506      94         1.979167
# 507      94         1.208333
# 508      94         0.937500
# 509      94         0.020833
#
# [510 rows x 2 columns]

# %%
# Filter out rows with zero or missing values in 'BF'
master_after_join = master_after_join[master_after_join['BF'] > 0]

# %%
master_after_join.head(5)
# Out:
#    Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0     0       1  108     1   1   1            15       1      1225       80
# 1     0       1    2     1   1   1            15       1      1227       80
# 2     2       2  130   518   1   1             0       1      1750       80
# 4   277     158  141     4   2   1            15       1      1225       78
# 5   205     122   99   256  18  11            15       1      1227       78
#
#    ...  Country_ID  Result_y  Margin        BR  Toss  Bat  Match_ID_y  Player  \
# 0  ...         8.0       3.0   154.0  53.00000   2.0  1.0       126.0      80
# 1  ...         8.0       6.0    73.0   2.00000   1.0  2.0       128.0      80
# 2  ...         8.0       3.0   167.0  67.89146   1.0  2.0       662.0      80
# 4  ...         8.0       3.0   154.0  53.00000   2.0  1.0       126.0      78
# 5  ...         8.0       6.0    73.0   2.00000   1.0  2.0       128.0      78
#
#    Batting Average  Bowling Average
# 0              0.0         2.733333
# 1              0.0         3.933333
# 2              1.0         4.600000
# 4            277.0         0.000000
# 5            102.5         0.000000
#
# [5 rows x 51 columns]

# %%
# Calculate Strike Rate (Batting) for each player
master_after_join['Strike Rate (Batting)'] = (master_after_join['Bat1'] / master_after_join['BF']) * 100

# Display the Strike Rate (Batting) for each player
print(master_after_join[['Player', 'Strike Rate (Batting)']])
# Out:
#      Player  Strike Rate (Batting)
# 0        80               0.000000
# 1        80               0.000000
# 2        80               1.538462
# 4        78             196.453901
# 5        78             207.070707
# ..      ...                    ...
# 502      57             200.970874
# 506      94             141.284404
# 507      94               3.846154
# 508      94             344.594595
# 509      94             187.500000
#
# [444 rows x 2 columns]

# %%
# Calculate Economy Rate (Bowling) for each player
master_after_join['Economy Rate (Bowling)'] = (master_after_join['Runs_y'] / master_after_join['Overs_y'])

# Display the Economy Rate (Bowling) for each player
print(master_after_join[['Player', 'Economy Rate (Bowling)']])
# Out:
#      Player  Economy Rate (Bowling)
# 0        80                0.845361
# 1        80                1.194332
# 2        80                1.674757
# 4        78                0.000000
# 5        78                0.000000
# ..      ...                     ...
# 502      57                1.000000
# 506      94                2.311436
# 507      94                1.367925
# 508      94                0.900000
# 509      94                0.020000
#
# [444 rows x 2 columns]

# %%
# Calculate the total Maiden Overs for each player
master_after_join['Maiden Overs Total'] = master_after_join['Mdns'].sum()

# Display the total Maiden Overs for each player
print(master_after_join[['Player', 'Maiden Overs Total']])
# Out:
#      Player  Maiden Overs Total
# 0        80                 262
# 1        80                 262
# 2        80                 262
# 4        78                 262
# 5        78                 262
# ..      ...                 ...
# 502      57                 262
# 506      94                 262
# 507      94                 262
# 508      94                 262
# 509      94                 262
#
# [444 rows x 2 columns]

# %%
# Step 1: Choose relevant performance metrics
batting_average = master_after_join['Batting Average']
bowling_average = master_after_join['Bowling Average']
strike_rate_batting = master_after_join['Strike Rate (Batting)']
economy_rate_bowling = master_after_join['Economy Rate (Bowling)']
maiden_overs = master_after_join['Maiden Overs Total']

#Step 2: Normalize the selected performance metrics using the min-max scaling
def min_max_scaling(x):
    return (x - x.min()) / (x.max() - x.min())

normalized_batting_average = min_max_scaling(batting_average)
normalized_bowling_average = min_max_scaling(bowling_average)
normalized_strike_rate_batting = min_max_scaling(strike_rate_batting)
normalized_economy_rate_bowling = min_max_scaling(economy_rate_bowling)
# normalized_maiden_overs = min_max_scaling(maiden_overs) we are not using this its giving NAN

# Step 3: Assign weights to each performance metric
batting_weight = 0.3
bowling_weight = 0.25
strike_rate_weight = 0.2
economy_rate_weight = 0.25


# Step 4: Calculate the composite performance score for each player
master_after_join['Player Performance Score'] = (
    batting_weight * normalized_batting_average +
    bowling_weight * normalized_bowling_average +
    strike_rate_weight * normalized_strike_rate_batting +
    economy_rate_weight * normalized_economy_rate_bowling )

# Step 5: Display the Player Performance Score for each player
print(master_after_join[['Player', 'Player Performance Score']])
# Out:
#      Player  Player Performance Score
# 0        80                  0.179688
# 1        80                  0.256694
# 2        80                  0.324796
# 4        78                  0.267204
# 5        78                  0.102335
# ..      ...                       ...
# 502      57                  0.327119
# 506      94                  0.423807
# 507      94                  0.166335
# 508      94                  0.363639
# 509      94                  0.177696
#
# [444 rows x 2 columns]

# %%
master_after_join.shape
# Out:
# (444, 55)

# %%
master_after_join.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns', 'Result_x',
#        'Opposition_y', 'Match_ID_x', 'Country', 'Country_ID', 'Result_y',
#        'Margin', 'BR', 'Toss', 'Bat', 'Match_ID_y', 'Player',
#        'Batting Average', 'Bowling Average', 'Strike Rate (Batting)',
#        'Economy Rate (Bowling)', 'Maiden Overs Total',
#        'Player Performance Score'],
#       dtype='object')

# %%
#Let's see the how data is distributed or Graphical analysis of all features
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.distplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# From above distribution we can see there are skewed data availabe so lets check again by using skew method
master_after_join.skew()
# Out:
# Bat1                       -0.233887
# Runs_x                     -0.346075
# BF                         -0.445824
# SR_x                       -0.039165
# 4s                          0.578048
# 6s                          2.952126
# Opposition_x               -0.516344
# Ground                      0.970068
# Match_ID                   -0.326713
# Batsman                    -0.105322
# Player_ID                   0.979422
# Month                      -0.134240
# Day                        -0.024541
# year                       -0.322862
# Overs_x                     1.262778
# Mdns                        1.473151
# Runs_y                      1.019444
# Wkts_x                      1.420556
# Econ                        0.740863
# Ave_x                       1.770862
# SR_y                        1.372929
# Bowler                     -0.097655
# Span                       -2.101193
# Mat                         3.289249
# Won                         3.289249
# Tied                        0.000000
# NR                          0.000000
# Runs                        2.546417
# Wkts_y                      2.866807
# Balls                       2.933363
# Ave_y                       3.219416
# RPO_x                       1.697543
# Score                       0.291136
# Overs_y                    -2.122394
# RPO_y                       0.256769
# Target                      0.058698
# Inns                        0.218229
# Result_x                   -0.044760
# Opposition_y               -0.301409
# Match_ID_x                 -0.326713
# Country                    -0.195242
# Country_ID                  2.054187
# Result_y                   -0.044760
# Margin                     -0.995123
# BR                          1.052424
# Toss                       -0.126806
# Bat                         0.218229
# Match_ID_y                 -0.337863
# Player                     -0.085164
# Batting Average             0.423427
# Bowling Average             1.558220
# Strike Rate (Batting)       5.879068
# Economy Rate (Bowling)      1.403963
# Maiden Overs Total          0.000000
# Player Performance Score    0.489816
# dtype: float64

# %%
master_after_join.columns
# Out:
# Index(['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
#        'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
#        'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
#        'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
#        'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns', 'Result_x',
#        'Opposition_y', 'Match_ID_x', 'Country', 'Country_ID', 'Result_y',
#        'Margin', 'BR', 'Toss', 'Bat', 'Match_ID_y', 'Player',
#        'Batting Average', 'Bowling Average', 'Strike Rate (Batting)',
#        'Economy Rate (Bowling)', 'Maiden Overs Total',
#        'Player Performance Score'],
#       dtype='object')

# %%
# Lets Separate the skewed columns or featres based on above thumb rule
master_after_join.skew()[(master_after_join.skew() >= 0.5) & (master_after_join.skew() >= -0.5)]
# Out:
# 4s                        0.578048
# 6s                        2.952126
# Ground                    0.970068
# Player_ID                 0.979422
# Overs_x                   1.262778
# Mdns                      1.473151
# Runs_y                    1.019444
# Wkts_x                    1.420556
# Econ                      0.740863
# Ave_x                     1.770862
# SR_y                      1.372929
# Mat                       3.289249
# Won                       3.289249
# Runs                      2.546417
# Wkts_y                    2.866807
# Balls                     2.933363
# Ave_y                     3.219416
# RPO_x                     1.697543
# Country_ID                2.054187
# BR                        1.052424
# Bowling Average           1.558220
# Strike Rate (Batting)     5.879068
# Economy Rate (Bowling)    1.403963
# dtype: float64

# %%
skew_col=['4s','6s','Ground','Player_ID','Overs_x','Mdns','Runs_y','Wkts_x','Econ','Ave_x','SR_y','Mat','Won','Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x','BR','Country_ID','Bowling Average','Bowling Average','Economy Rate (Bowling)']
len(skew_col)
# Out:
# 23

# %%
# Now almost All skewness we removed so move further
#Let's check for the Outliers
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.boxplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# So from graph we can see the outlier are present in the some columns so lets remove them first 
outliers_col=['Margin', 'BR','Overs_y','Target','Ground','Span','Strike Rate (Batting)','Player Performance Score']

# %%
# Remove the outliers by using Z score

z_score=zscore(master_after_join[outliers_col])
z_score_abs=np.abs(z_score)
filter_entry=(z_score_abs<3).all(axis=1)
master_after_join=master_after_join[filter_entry]
master_after_join.head()
# Out:
#    Bat1  Runs_x   BF  SR_x  4s  6s  Opposition_x  Ground  Match_ID  Batsman  \
# 0     0       1  108     1   1   1            15       1      1225       80
# 1     0       1    2     1   1   1            15       1      1227       80
# 2     2       2  130   518   1   1             0       1      1750       80
# 4   277     158  141     4   2   1            15       1      1225       78
# 5   205     122   99   256  18  11            15       1      1227       78
#
#    ...  Toss  Bat  Match_ID_y  Player  Batting Average  Bowling Average  \
# 0  ...   2.0  1.0       126.0      80              0.0         2.733333
# 1  ...   1.0  2.0       128.0      80              0.0         3.933333
# 2  ...   1.0  2.0       662.0      80              1.0         4.600000
# 4  ...   2.0  1.0       126.0      78            277.0         0.000000
# 5  ...   1.0  2.0       128.0      78            102.5         0.000000
#
#    Strike Rate (Batting)  Economy Rate (Bowling)  Maiden Overs Total  \
# 0               0.000000                0.845361                 262
# 1               0.000000                1.194332                 262
# 2               1.538462                1.674757                 262
# 4             196.453901                0.000000                 262
# 5             207.070707                0.000000                 262
#
#    Player Performance Score
# 0                  0.179688
# 1                  0.256694
# 2                  0.324796
# 4                  0.267204
# 5                  0.102335
#
# [5 rows x 55 columns]

# %%
#Let's recheck for the Outliers
plt.figure(figsize=(15,20))
plotnumber=1
for column in master_after_join:
    if plotnumber<=60:
        ax=plt.subplot(10,6,plotnumber)
        sns.boxplot(master_after_join[column])
        plt.xlabel(column,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
# Use 'Player Performance Score' as the target variable for the prediction model

x = master_after_join[['Bat1', 'Runs_x', 'BF', 'SR_x', '4s', '6s', 'Opposition_x', 'Ground',
          'Match_ID', 'Batsman', 'Player_ID', 'Month', 'Day', 'year', 'Overs_x',
          'Mdns', 'Runs_y', 'Wkts_x', 'Econ', 'Ave_x', 'SR_y', 'Bowler', 'Span',
          'Mat', 'Won', 'Tied', 'NR', 'Runs', 'Wkts_y', 'Balls', 'Ave_y', 'RPO_x',
          'Result_x', 'Margin', 'BR', 'Toss', 'Bat', 'Opposition_y', 'Match_ID_x',
          'Country', 'Country_ID', 'Score', 'Overs_y', 'RPO_y', 'Target', 'Inns',
          'Result_y', 'Match_ID_y']]

y = master_after_join['Player Performance Score']  # Target column

# %%
print(x.shape, y.shape)
# Out:
# (408, 48) (408,)

# %%
# data stadardization

scale=StandardScaler()
x_scaled=scale.fit_transform(x)

# %%
#check multicolinearity

vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(x_scaled,i) for i in range(x_scaled.shape[1])]
vif["featurs"]=x.columns
print(vif)
# Out:
#              vif       featurs
# 0   3.236749e+02          Bat1
# 1   3.272782e+02        Runs_x
# 2   1.320922e+00            BF
# 3   1.307263e+00          SR_x
# 4   1.475799e+00            4s
# 5   1.323690e+00            6s
# 6   9.955071e+01  Opposition_x
# 7            inf        Ground
# 8            inf      Match_ID
# 9   3.698207e+04       Batsman
# 10  1.314561e+00     Player_ID
# 11  2.534057e+01         Month
# 12  1.602917e+00           Day
# 13  5.465632e+02          year
# 14  2.529241e+00       Overs_x
# 15  3.353339e+00          Mdns
# 16  4.709796e+00        Runs_y
# 17  3.729181e+00        Wkts_x
# 18  4.896810e+00          Econ
# 19  5.506742e+00         Ave_x
# 20  5.854406e+00          SR_y
# 21  3.697764e+04        Bowler
# 22           inf          Span
# 23           inf           Mat
# 24           inf           Won
# 25           NaN          Tied
# 26           NaN            NR
# 27           inf          Runs
# 28           inf        Wkts_y
# 29           inf         Balls
# 30           inf         Ave_y
# 31           inf         RPO_x
# 32           inf      Result_x
# 33  1.701079e+00        Margin
# 34  2.170807e+00            BR
# 35  1.560636e+00          Toss
# 36           inf           Bat
# 37  1.000806e+02  Opposition_y
# 38           inf    Match_ID_x
# 39  2.480307e+00       Country
# 40  2.155099e+00    Country_ID
# 41  1.079358e+02         Score
# 42  3.484388e+01       Overs_y
# 43  6.380615e+01         RPO_y
# 44  6.326810e+00        Target
# 45           inf          Inns
# 46           inf      Result_y
# 47  6.741544e+04    Match_ID_y

# %%
pca=PCA()
pca.fit_transform(x_scaled)
# Out:
# array([[-1.71555826e+00,  4.05884099e-01,  1.85348981e+00, ...,
#          9.33577354e-16, -1.40455281e-16, -6.55524995e-16],
#        [-1.69510040e+00,  1.50837618e+00,  2.17212355e+00, ...,
#         -1.18292206e-15, -7.19901695e-16, -2.75383950e-16],
#        [-3.71259227e+00,  4.42855489e+00, -2.44666196e+00, ...,
#          1.88381765e-16,  6.91278054e-16, -5.92807786e-16],
#        ...,
#        [ 4.50361681e+00,  3.60959401e+00,  8.73510440e-01, ...,
#         -2.99231578e-16,  1.72099846e-17, -1.13047320e-16],
#        [ 3.97481363e+00,  3.75290372e+00,  1.20113449e+00, ...,
#          1.80276860e-16, -7.36743406e-17,  2.01866468e-16],
#        [ 4.94412302e+00,  4.68456844e-01,  7.36605342e-01, ...,
#          2.05722965e-16,  1.68392082e-16, -1.80547797e-17]])

# %%
# Lets plot the PCA plot to select the best components
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Principal Components")
plt.ylabel("Variance Covered")
plt.title("PCA Plot")
# Out:
# Text(0.5, 1.0, 'PCA Plot')

# %%
pca=PCA(n_components=19)
pca_x=pca.fit_transform(x_scaled)
pca_x=pd.DataFrame(pca_x,columns=['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19'])
pca_x
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -1.715558  0.405884  1.853490  4.041821  0.450206 -2.955397  0.621476
# 1   -1.695100  1.508376  2.172124  4.024685 -0.967734 -2.800127 -2.523633
# 2   -3.712592  4.428555 -2.446662  1.454384 -0.750505 -0.348771 -0.759009
# 3   -0.978327 -2.724740  1.068914  2.708875 -1.417543 -0.832131  1.534131
# 4   -0.425902 -3.345142  0.814003  2.180715 -3.359272 -1.043728 -1.480476
# ..        ...       ...       ...       ...       ...       ...       ...
# 403  4.264589  2.509735  0.424732 -2.362466 -0.267979  0.740181  0.607153
# 404  3.532961  2.543756 -1.597902  1.216960  2.269680  3.005442  0.781169
# 405  4.503617  3.609594  0.873510 -0.622927  0.322380 -0.396016 -1.871963
# 406  3.974814  3.752904  1.201134 -2.444935 -0.326141  1.403284 -0.333149
# 407  4.944123  0.468457  0.736605 -2.427006 -0.589758  0.248583 -0.572550
#
#           PC8       PC9      PC10      PC11      PC12      PC13      PC14  \
# 0    1.139169  1.238982 -0.836321  1.162174 -0.401364 -0.187779 -0.422133
# 1   -1.915688 -0.151857  0.680963  0.133825 -0.037708  0.475446  0.176649
# 2   -0.944424  0.021618 -1.619105 -0.209672  0.902524 -0.222268 -2.716124
# 3    2.020254  0.955674 -0.772978  1.213669  1.175079 -2.165321 -0.617606
# 4   -1.462676 -0.961912  0.919464  2.529386  1.864371  0.423266  0.363107
# ..        ...       ...       ...       ...       ...       ...       ...
# 403 -1.067221  1.548211 -1.850709  0.384054 -0.387274  1.035365  1.854229
# 404  2.604466  0.016765 -0.442147  0.513594  0.125594  1.050503  1.954158
# 405 -2.103838 -1.546398  0.745173 -0.000052  0.528785 -2.419767  0.258200
# 406 -0.480823  1.324068 -1.980160 -0.263011  0.639933 -0.240870  1.572840
# 407 -0.367929  0.217001 -0.269300 -0.958018  2.624763  2.008787  2.344409
#
#          PC15      PC16      PC17      PC18      PC19
# 0    0.057189 -1.518510 -0.062652  1.163590 -1.156244
# 1   -1.556511  0.470715  1.615023 -0.275578 -1.031961
# 2    1.199006 -1.087473  0.092507  0.049903  0.833417
# 3   -1.239795  0.217446 -0.793116  1.163687 -0.775299
# 4   -1.198708 -0.200602 -0.463910 -1.166012 -1.045293
# ..        ...       ...       ...       ...       ...
# 403 -0.881400 -0.987535  0.179824  1.344071 -1.112531
# 404  0.475130 -1.187265 -0.244805  0.392383  0.607496
# 405  1.172513 -1.333015  0.509634 -1.073383 -0.617757
# 406 -1.137106  1.149121  0.793669  0.473643 -0.384410
# 407  0.245959  0.220712 -0.130630 -0.272442  0.984934
#
# [408 rows x 19 columns]

# %% [markdown]
# * ### Model building

# %%
# Lets select the proper random state to build best model by using LogisticRegression

acc_score_test = 0
acc_score_train = 0
rand_state = 0
for i in range(1,200):
    
    x_train,x_test,y_train,y_test = train_test_split(pca_x,y,test_size=0.3,random_state= i )
    
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    
    y_pred=lr.predict(x_train) # prediction on train data
    r1 =r2_score(y_train,y_pred) # accuracy check on train data
    
    pred = lr.predict(x_test)   #prediction on test data
    r2 =r2_score(y_test,pred) #accuracy check on test data
    
    if r2 > acc_score_test and r1 > acc_score_train: # selecting max score accuracy
        acc_score_test = r2
        acc_score_train = r1
        rand_state = i
    print(f"at random sate {i}, the training accuracy is:- {acc_score_train}")
    print(f"at random sate {i}, the testing accuracy is:- {acc_score_test}")
    print("\n")
print('Best Training accuracy_score is {} on random state {}'.format(acc_score_train,rand_state))
print('Best Testing accuracy_score is {} on random state {}'.format(acc_score_test,rand_state))
# Out:
# at random sate 1, the training accuracy is:- 0.8415580290725087
# at random sate 1, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 2, the training accuracy is:- 0.8415580290725087
# at random sate 2, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 3, the training accuracy is:- 0.8415580290725087
# at random sate 3, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 4, the training accuracy is:- 0.8415580290725087
# at random sate 4, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 5, the training accuracy is:- 0.8415580290725087
# at random sate 5, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 6, the training accuracy is:- 0.8415580290725087
# at random sate 6, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 7, the training accuracy is:- 0.8415580290725087
# at random sate 7, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 8, the training accuracy is:- 0.8415580290725087
# at random sate 8, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 9, the training accuracy is:- 0.8415580290725087
# at random sate 9, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 10, the training accuracy is:- 0.8415580290725087
# at random sate 10, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 11, the training accuracy is:- 0.8415580290725087
# at random sate 11, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 12, the training accuracy is:- 0.8415580290725087
# at random sate 12, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 13, the training accuracy is:- 0.8415580290725087
# at random sate 13, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 14, the training accuracy is:- 0.8415580290725087
# at random sate 14, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 15, the training accuracy is:- 0.8415580290725087
# at random sate 15, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 16, the training accuracy is:- 0.8415580290725087
# at random sate 16, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 17, the training accuracy is:- 0.8415580290725087
# at random sate 17, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 18, the training accuracy is:- 0.8415580290725087
# at random sate 18, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 19, the training accuracy is:- 0.8415580290725087
# at random sate 19, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 20, the training accuracy is:- 0.8415580290725087
# at random sate 20, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 21, the training accuracy is:- 0.8415580290725087
# at random sate 21, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 22, the training accuracy is:- 0.8415580290725087
# at random sate 22, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 23, the training accuracy is:- 0.8415580290725087
# at random sate 23, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 24, the training accuracy is:- 0.8415580290725087
# at random sate 24, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 25, the training accuracy is:- 0.8415580290725087
# at random sate 25, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 26, the training accuracy is:- 0.8415580290725087
# at random sate 26, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 27, the training accuracy is:- 0.8415580290725087
# at random sate 27, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 28, the training accuracy is:- 0.8415580290725087
# at random sate 28, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 29, the training accuracy is:- 0.8415580290725087
# at random sate 29, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 30, the training accuracy is:- 0.8415580290725087
# at random sate 30, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 31, the training accuracy is:- 0.8415580290725087
# at random sate 31, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 32, the training accuracy is:- 0.8415580290725087
# at random sate 32, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 33, the training accuracy is:- 0.8415580290725087
# at random sate 33, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 34, the training accuracy is:- 0.8415580290725087
# at random sate 34, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 35, the training accuracy is:- 0.8415580290725087
# at random sate 35, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 36, the training accuracy is:- 0.8415580290725087
# at random sate 36, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 37, the training accuracy is:- 0.8415580290725087
# at random sate 37, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 38, the training accuracy is:- 0.8415580290725087
# at random sate 38, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 39, the training accuracy is:- 0.8415580290725087
# at random sate 39, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 40, the training accuracy is:- 0.8415580290725087
# at random sate 40, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 41, the training accuracy is:- 0.8415580290725087
# at random sate 41, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 42, the training accuracy is:- 0.8415580290725087
# at random sate 42, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 43, the training accuracy is:- 0.8415580290725087
# at random sate 43, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 44, the training accuracy is:- 0.8415580290725087
# at random sate 44, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 45, the training accuracy is:- 0.8415580290725087
# at random sate 45, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 46, the training accuracy is:- 0.8415580290725087
# at random sate 46, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 47, the training accuracy is:- 0.8415580290725087
# at random sate 47, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 48, the training accuracy is:- 0.8415580290725087
# at random sate 48, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 49, the training accuracy is:- 0.8415580290725087
# at random sate 49, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 50, the training accuracy is:- 0.8415580290725087
# at random sate 50, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 51, the training accuracy is:- 0.8415580290725087
# at random sate 51, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 52, the training accuracy is:- 0.8415580290725087
# at random sate 52, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 53, the training accuracy is:- 0.8415580290725087
# at random sate 53, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 54, the training accuracy is:- 0.8415580290725087
# at random sate 54, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 55, the training accuracy is:- 0.8415580290725087
# at random sate 55, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 56, the training accuracy is:- 0.8415580290725087
# at random sate 56, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 57, the training accuracy is:- 0.8415580290725087
# at random sate 57, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 58, the training accuracy is:- 0.8415580290725087
# at random sate 58, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 59, the training accuracy is:- 0.8415580290725087
# at random sate 59, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 60, the training accuracy is:- 0.8415580290725087
# at random sate 60, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 61, the training accuracy is:- 0.8415580290725087
# at random sate 61, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 62, the training accuracy is:- 0.8415580290725087
# at random sate 62, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 63, the training accuracy is:- 0.8415580290725087
# at random sate 63, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 64, the training accuracy is:- 0.8415580290725087
# at random sate 64, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 65, the training accuracy is:- 0.8415580290725087
# at random sate 65, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 66, the training accuracy is:- 0.8415580290725087
# at random sate 66, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 67, the training accuracy is:- 0.8415580290725087
# at random sate 67, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 68, the training accuracy is:- 0.8415580290725087
# at random sate 68, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 69, the training accuracy is:- 0.8415580290725087
# at random sate 69, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 70, the training accuracy is:- 0.8415580290725087
# at random sate 70, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 71, the training accuracy is:- 0.8415580290725087
# at random sate 71, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 72, the training accuracy is:- 0.8415580290725087
# at random sate 72, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 73, the training accuracy is:- 0.8415580290725087
# at random sate 73, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 74, the training accuracy is:- 0.8415580290725087
# at random sate 74, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 75, the training accuracy is:- 0.8415580290725087
# at random sate 75, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 76, the training accuracy is:- 0.8415580290725087
# at random sate 76, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 77, the training accuracy is:- 0.8415580290725087
# at random sate 77, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 78, the training accuracy is:- 0.8415580290725087
# at random sate 78, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 79, the training accuracy is:- 0.8415580290725087
# at random sate 79, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 80, the training accuracy is:- 0.8415580290725087
# at random sate 80, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 81, the training accuracy is:- 0.8415580290725087
# at random sate 81, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 82, the training accuracy is:- 0.8415580290725087
# at random sate 82, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 83, the training accuracy is:- 0.8415580290725087
# at random sate 83, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 84, the training accuracy is:- 0.8415580290725087
# at random sate 84, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 85, the training accuracy is:- 0.8415580290725087
# at random sate 85, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 86, the training accuracy is:- 0.8415580290725087
# at random sate 86, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 87, the training accuracy is:- 0.8415580290725087
# at random sate 87, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 88, the training accuracy is:- 0.8415580290725087
# at random sate 88, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 89, the training accuracy is:- 0.8415580290725087
# at random sate 89, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 90, the training accuracy is:- 0.8415580290725087
# at random sate 90, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 91, the training accuracy is:- 0.8415580290725087
# at random sate 91, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 92, the training accuracy is:- 0.8415580290725087
# at random sate 92, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 93, the training accuracy is:- 0.8415580290725087
# at random sate 93, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 94, the training accuracy is:- 0.8415580290725087
# at random sate 94, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 95, the training accuracy is:- 0.8415580290725087
# at random sate 95, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 96, the training accuracy is:- 0.8415580290725087
# at random sate 96, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 97, the training accuracy is:- 0.8415580290725087
# at random sate 97, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 98, the training accuracy is:- 0.8415580290725087
# at random sate 98, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 99, the training accuracy is:- 0.8415580290725087
# at random sate 99, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 100, the training accuracy is:- 0.8415580290725087
# at random sate 100, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 101, the training accuracy is:- 0.8415580290725087
# at random sate 101, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 102, the training accuracy is:- 0.8415580290725087
# at random sate 102, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 103, the training accuracy is:- 0.8415580290725087
# at random sate 103, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 104, the training accuracy is:- 0.8415580290725087
# at random sate 104, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 105, the training accuracy is:- 0.8415580290725087
# at random sate 105, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 106, the training accuracy is:- 0.8415580290725087
# at random sate 106, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 107, the training accuracy is:- 0.8415580290725087
# at random sate 107, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 108, the training accuracy is:- 0.8415580290725087
# at random sate 108, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 109, the training accuracy is:- 0.8415580290725087
# at random sate 109, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 110, the training accuracy is:- 0.8415580290725087
# at random sate 110, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 111, the training accuracy is:- 0.8415580290725087
# at random sate 111, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 112, the training accuracy is:- 0.8415580290725087
# at random sate 112, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 113, the training accuracy is:- 0.8415580290725087
# at random sate 113, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 114, the training accuracy is:- 0.8415580290725087
# at random sate 114, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 115, the training accuracy is:- 0.8415580290725087
# at random sate 115, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 116, the training accuracy is:- 0.8415580290725087
# at random sate 116, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 117, the training accuracy is:- 0.8415580290725087
# at random sate 117, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 118, the training accuracy is:- 0.8415580290725087
# at random sate 118, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 119, the training accuracy is:- 0.8415580290725087
# at random sate 119, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 120, the training accuracy is:- 0.8415580290725087
# at random sate 120, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 121, the training accuracy is:- 0.8415580290725087
# at random sate 121, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 122, the training accuracy is:- 0.8415580290725087
# at random sate 122, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 123, the training accuracy is:- 0.8415580290725087
# at random sate 123, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 124, the training accuracy is:- 0.8415580290725087
# at random sate 124, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 125, the training accuracy is:- 0.8415580290725087
# at random sate 125, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 126, the training accuracy is:- 0.8415580290725087
# at random sate 126, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 127, the training accuracy is:- 0.8415580290725087
# at random sate 127, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 128, the training accuracy is:- 0.8415580290725087
# at random sate 128, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 129, the training accuracy is:- 0.8415580290725087
# at random sate 129, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 130, the training accuracy is:- 0.8415580290725087
# at random sate 130, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 131, the training accuracy is:- 0.8415580290725087
# at random sate 131, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 132, the training accuracy is:- 0.8415580290725087
# at random sate 132, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 133, the training accuracy is:- 0.8415580290725087
# at random sate 133, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 134, the training accuracy is:- 0.8415580290725087
# at random sate 134, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 135, the training accuracy is:- 0.8415580290725087
# at random sate 135, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 136, the training accuracy is:- 0.8415580290725087
# at random sate 136, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 137, the training accuracy is:- 0.8415580290725087
# at random sate 137, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 138, the training accuracy is:- 0.8415580290725087
# at random sate 138, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 139, the training accuracy is:- 0.8415580290725087
# at random sate 139, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 140, the training accuracy is:- 0.8415580290725087
# at random sate 140, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 141, the training accuracy is:- 0.8415580290725087
# at random sate 141, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 142, the training accuracy is:- 0.8415580290725087
# at random sate 142, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 143, the training accuracy is:- 0.8415580290725087
# at random sate 143, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 144, the training accuracy is:- 0.8415580290725087
# at random sate 144, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 145, the training accuracy is:- 0.8415580290725087
# at random sate 145, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 146, the training accuracy is:- 0.8415580290725087
# at random sate 146, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 147, the training accuracy is:- 0.8415580290725087
# at random sate 147, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 148, the training accuracy is:- 0.8415580290725087
# at random sate 148, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 149, the training accuracy is:- 0.8415580290725087
# at random sate 149, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 150, the training accuracy is:- 0.8415580290725087
# at random sate 150, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 151, the training accuracy is:- 0.8415580290725087
# at random sate 151, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 152, the training accuracy is:- 0.8415580290725087
# at random sate 152, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 153, the training accuracy is:- 0.8415580290725087
# at random sate 153, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 154, the training accuracy is:- 0.8415580290725087
# at random sate 154, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 155, the training accuracy is:- 0.8415580290725087
# at random sate 155, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 156, the training accuracy is:- 0.8415580290725087
# at random sate 156, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 157, the training accuracy is:- 0.8415580290725087
# at random sate 157, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 158, the training accuracy is:- 0.8415580290725087
# at random sate 158, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 159, the training accuracy is:- 0.8415580290725087
# at random sate 159, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 160, the training accuracy is:- 0.8415580290725087
# at random sate 160, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 161, the training accuracy is:- 0.8415580290725087
# at random sate 161, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 162, the training accuracy is:- 0.8415580290725087
# at random sate 162, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 163, the training accuracy is:- 0.8415580290725087
# at random sate 163, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 164, the training accuracy is:- 0.8415580290725087
# at random sate 164, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 165, the training accuracy is:- 0.8415580290725087
# at random sate 165, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 166, the training accuracy is:- 0.8415580290725087
# at random sate 166, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 167, the training accuracy is:- 0.8415580290725087
# at random sate 167, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 168, the training accuracy is:- 0.8415580290725087
# at random sate 168, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 169, the training accuracy is:- 0.8415580290725087
# at random sate 169, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 170, the training accuracy is:- 0.8415580290725087
# at random sate 170, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 171, the training accuracy is:- 0.8415580290725087
# at random sate 171, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 172, the training accuracy is:- 0.8415580290725087
# at random sate 172, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 173, the training accuracy is:- 0.8415580290725087
# at random sate 173, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 174, the training accuracy is:- 0.8415580290725087
# at random sate 174, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 175, the training accuracy is:- 0.8415580290725087
# at random sate 175, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 176, the training accuracy is:- 0.8415580290725087
# at random sate 176, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 177, the training accuracy is:- 0.8415580290725087
# at random sate 177, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 178, the training accuracy is:- 0.8415580290725087
# at random sate 178, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 179, the training accuracy is:- 0.8415580290725087
# at random sate 179, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 180, the training accuracy is:- 0.8415580290725087
# at random sate 180, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 181, the training accuracy is:- 0.8415580290725087
# at random sate 181, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 182, the training accuracy is:- 0.8415580290725087
# at random sate 182, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 183, the training accuracy is:- 0.8415580290725087
# at random sate 183, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 184, the training accuracy is:- 0.8415580290725087
# at random sate 184, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 185, the training accuracy is:- 0.8415580290725087
# at random sate 185, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 186, the training accuracy is:- 0.8415580290725087
# at random sate 186, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 187, the training accuracy is:- 0.8415580290725087
# at random sate 187, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 188, the training accuracy is:- 0.8415580290725087
# at random sate 188, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 189, the training accuracy is:- 0.8415580290725087
# at random sate 189, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 190, the training accuracy is:- 0.8415580290725087
# at random sate 190, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 191, the training accuracy is:- 0.8415580290725087
# at random sate 191, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 192, the training accuracy is:- 0.8415580290725087
# at random sate 192, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 193, the training accuracy is:- 0.8415580290725087
# at random sate 193, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 194, the training accuracy is:- 0.8415580290725087
# at random sate 194, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 195, the training accuracy is:- 0.8415580290725087
# at random sate 195, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 196, the training accuracy is:- 0.8415580290725087
# at random sate 196, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 197, the training accuracy is:- 0.8415580290725087
# at random sate 197, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 198, the training accuracy is:- 0.8415580290725087
# at random sate 198, the testing accuracy is:- 0.8120376086455556
#
#
# at random sate 199, the training accuracy is:- 0.8415580290725087
# at random sate 199, the testing accuracy is:- 0.8120376086455556
#
#
# Best Training accuracy_score is 0.8415580290725087 on random state 1
# Best Testing accuracy_score is 0.8120376086455556 on random state 1

# %%
rand_state
# Out:
# 1

# %%
#Lets split for train and test data
x_train,x_test,y_train,y_test = train_test_split(pca_x,y,test_size=0.3,random_state= rand_state )

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (285, 19)
# (123, 19)
# (285,)
# (123,)

# %%
LR= LinearRegression()

dt=DecisionTreeRegressor()

ada=AdaBoostRegressor()
gb=GradientBoostingRegressor()

rfc= RandomForestRegressor()


xgb=xgb.XGBRegressor()

knn=KNeighborsRegressor()



models=[]
models.append(('LinearRegression', LR))
models.append(('DecisionTreeRegressor', dt))
models.append(('AdaBoostRegressor', ada))
models.append(('GradientBoostingRegressor', gb))
models.append(('RandomForestRegressor', rfc))
models.append(('XGBRegressor', xgb))
models.append(('KNeighborsRegressor', knn))

# %%
m=[]
score=[]
score2=[]
cv_score=[]
MAE_score=[]
MSE_score=[]
for name, model in models:
    print('***********************',name,'***********************')
    m.append(name)
    model.fit(x_train, y_train)
    print(model)
    y_pred=model.predict(x_train)
    AS=r2_score(y_train,y_pred)
    print("Train Report:",AS)
    score.append(AS*100)
    
    pred=model.predict(x_test)
    AS2=r2_score(y_test,pred)
    print("Test Report:",AS2)
    score2.append(AS2*100)
    MAE=mae(y_test,pred)
    print("Mean Squered Error:",MAE)
    MAE_score.append(MAE*100)
    MSE=mse(y_test,pred)
    print("Mean Absolute Error:", MSE)
    MSE_score.append(MSE*100)
    
    accuracies= cross_val_score(model,x,y, cv=2)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    cv_score.append(accuracies.mean()*100)
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
    print('\n')
# Out:
# *********************** LinearRegression ***********************
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Train Report: 0.8415580290725087
# Test Report: 0.8120376086455556
# Mean Squered Error: 0.039565778654232324
# Mean Absolute Error: 0.002852207558491349
# Accuracy: 88.98 %
# Standard Deviation: 0.56 %
#
#
# *********************** DecisionTreeRegressor ***********************
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')
# Train Report: 0.9999995605923878
# Test Report: 0.2765169495899903
# Mean Squered Error: 0.07954167201756226
# Mean Absolute Error: 0.010978386739763165
# Accuracy: 79.85 %
# Standard Deviation: 2.37 %
#
#
# *********************** AdaBoostRegressor ***********************
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=None)
# Train Report: 0.82522005758466
# Test Report: 0.5372722191523335
# Mean Squered Error: 0.06959312911124672
# Mean Absolute Error: 0.0070215943974072876
# Accuracy: 85.65 %
# Standard Deviation: 1.76 %
#
#
# *********************** GradientBoostingRegressor ***********************
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
# Train Report: 0.9868898636376777
# Test Report: 0.6846152655672251
# Mean Squered Error: 0.05333605825398694
# Mean Absolute Error: 0.004785759092017838
# Accuracy: 93.86 %
# Standard Deviation: 2.83 %
#
#
# *********************** RandomForestRegressor ***********************
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)
# Train Report: 0.9323368620309327
# Test Report: 0.5993911419825833
# Mean Squered Error: 0.06202606648355356
# Mean Absolute Error: 0.0060789799736118665
# Accuracy: 90.41 %
# Standard Deviation: 1.56 %
#
#
# *********************** XGBRegressor ***********************
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, objective='reg:squarederror',
#              predictor='auto', random_state=0, reg_alpha=0, ...)
# Train Report: 0.9999643327441963
# Test Report: 0.7028608635280236
# Mean Squered Error: 0.050365350032374544
# Mean Absolute Error: 0.004508893959381542
# Accuracy: 90.71 %
# Standard Deviation: 4.55 %
#
#
# *********************** KNeighborsRegressor ***********************
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')
# Train Report: 0.7237043543414674
# Test Report: 0.5182154766281781
# Mean Squered Error: 0.06624413170122229
# Mean Absolute Error: 0.007310768123469983
# Accuracy: -37.30 %
# Standard Deviation: 8.33 %

# %%
print(len(m),len(score),len(score2),len(cv_score),len(MAE_score),len(MSE_score))
# Out:
# 7 7 7 7 7 7

# %%
result = pd.DataFrame({'Model': m, 'Accuracy_train_score': score,'Accuracy_test_score': score2 ,'Cross_val_score':cv_score, 'MAE_score':MAE_score,'MSE_score':MSE_score })
result
# Out:
#                        Model  Accuracy_train_score  Accuracy_test_score  \
# 0           LinearRegression             84.155803            81.203761
# 1      DecisionTreeRegressor             99.999956            27.651695
# 2          AdaBoostRegressor             82.522006            53.727222
# 3  GradientBoostingRegressor             98.688986            68.461527
# 4      RandomForestRegressor             93.233686            59.939114
# 5               XGBRegressor             99.996433            70.286086
# 6        KNeighborsRegressor             72.370435            51.821548
#
#    Cross_val_score  MAE_score  MSE_score
# 0        88.982171   3.956578   0.285221
# 1        79.847200   7.954167   1.097839
# 2        85.645050   6.959313   0.702159
# 3        93.861167   5.333606   0.478576
# 4        90.409849   6.202607   0.607898
# 5        90.708009   5.036535   0.450889
# 6       -37.299920   6.624413   0.731077

# %%
result['lest_diff']=(result['Accuracy_test_score']-result['Cross_val_score'])
result
# Out:
#                        Model  Accuracy_train_score  Accuracy_test_score  \
# 0           LinearRegression             84.155803            81.203761
# 1      DecisionTreeRegressor             99.999956            27.651695
# 2          AdaBoostRegressor             82.522006            53.727222
# 3  GradientBoostingRegressor             98.688986            68.461527
# 4      RandomForestRegressor             93.233686            59.939114
# 5               XGBRegressor             99.996433            70.286086
# 6        KNeighborsRegressor             72.370435            51.821548
#
#    Cross_val_score  MAE_score  MSE_score  lest_diff
# 0        88.982171   3.956578   0.285221  -7.778410
# 1        79.847200   7.954167   1.097839 -52.195505
# 2        85.645050   6.959313   0.702159 -31.917828
# 3        93.861167   5.333606   0.478576 -25.399640
# 4        90.409849   6.202607   0.607898 -30.470735
# 5        90.708009   5.036535   0.450889 -20.421922
# 6       -37.299920   6.624413   0.731077  89.121467

# %%
# Hyper tuning by using RandomizedSearchCV With RandomForestClassifier

para={'n_jobs':range(1,55)}
rand=RandomizedSearchCV(estimator=LR, cv=5,param_distributions=para)
rand.fit(x_train,y_train)

rand.best_params_
# Out:
# {'n_jobs': 42}

# %%
LR= LinearRegression(n_jobs= 17)

LR.fit(x_train,y_train)
y_pred=ada.predict(x_train)
AS=r2_score(y_train,y_pred)
print("Train Report:",AS*100) 
pred=LR.predict(x_test)
AS2=r2_score(y_test,pred)
print("Test Report:",AS2*100)
MAE=mae(y_test,pred)
print("Mean Squered Error:",MAE)
MSE=mse(y_test,pred)
print("Mean Absolute Error:", MSE)
    
accuracies= cross_val_score(LR,x_scaled, y, cv=5)
print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
cv_score.append(accuracies.mean()*100)
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Train Report: 82.522005758466
# Test Report: 81.20376086455556
# Mean Squered Error: 0.039565778654232324
# Mean Absolute Error: 0.002852207558491349
# Accuracy: 91.64 %
# Standard Deviation: 1.32 %
